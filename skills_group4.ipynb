# %% [markdown]
# # Articles

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#import article table
article = pd.read_csv("/content/drive/MyDrive/Group 4/articles.APOE.csv")
article.head()
# Out:
#        PMID                                              Title  \
# 0  10545039  No evidence of association between apolipoprot...
# 1  10558867  Association of the estrogen receptor alpha gen...
# 2  10560469  Initial evaluation of suspected dementia. Aski...
# 3  10563634  APOE-epsilon4 is associated with less frontal ...
# 4  10570509  [Frequency of the APOE-4 allele in Alzheimer's...
#
#                                             Abstract       ISSN  \
# 0  The survival motor neuron (SMN) gene is presen...  0960-8966
# 1  Alzheimer's disease (AD) is a multifactorial d...  0006-291X
# 2  The initial clinical approach to suspected dem...  0032-5481
# 3  To test the hypothesis that the e4 allele of A...  0028-3878
# 4  Patients with late-onset Alzheimer's disease s...  0025-7753
#
#                                              Journal                 Location  \
# 0                      Neuromuscular disorders : NMD                (9) 372-5
# 1  Biochemical and biophysical research communica...              (265) 335-8
# 2                              Postgraduate medicine  (106) 72-6, 79-80, 82-3
# 3                                          Neurology             (53) 1825-32
# 4                                   Medicina clinica              (113) 441-3
#
#    Year FirstAuthorForename FirstAuthorLastname FirstAuthorInitials  \
# 0  1999                 K E            Morrison                  KE
# 1  1999                 M L              Brandi                  ML
# 2  1999                 D C            Steffens                  DC
# 3  1999                   C             Geroldi                   C
# 4  1999                   V             Alvarez                   V
#
#                               FirstAuthorAffiliation
# 0  Neurosciences Group, Institiute of Molecular M...
# 1  Department of Clinical Physiopathology, Univer...
# 2  Department of Psychiatry and Behavioral Scienc...
# 3     IRCCS San Giovanni di Dio-FBF, Brescia, Italy.
# 4  Laboratorio de Genética Molecular, Instituto R...

# %%
article.shape
# Out:
# (6304, 11)

# %%
#merge forename and lastname text column together to fullname
article["FirstAuthorFullname"] = article["FirstAuthorForename"].fillna("") + ' ' + article["FirstAuthorLastname"]
article
# Out:
#           PMID                                              Title  \
# 0     10545039  No evidence of association between apolipoprot...
# 1     10558867  Association of the estrogen receptor alpha gen...
# 2     10560469  Initial evaluation of suspected dementia. Aski...
# 3     10563634  APOE-epsilon4 is associated with less frontal ...
# 4     10570509  [Frequency of the APOE-4 allele in Alzheimer's...
# ...        ...                                                ...
# 6299  38071369  Spinal apolipoprotein E is involved in inflamm...
# 6300  38073392  Differential Associations of APOEɛ2 and APOEɛ4...
# 6301  38083439  Predictive Modeling Of Alzheimer's Disease Pro...
# 6302  38084238  The associations of PON1 and APOE polymorphism...
# 6303  38091051  Multivariate investigation of aging in mouse m...
#
#                                                Abstract       ISSN  \
# 0     The survival motor neuron (SMN) gene is presen...  0960-8966
# 1     Alzheimer's disease (AD) is a multifactorial d...  0006-291X
# 2     The initial clinical approach to suspected dem...  0032-5481
# 3     To test the hypothesis that the e4 allele of A...  0028-3878
# 4     Patients with late-onset Alzheimer's disease s...  0025-7753
# ...                                                 ...        ...
# 6299  Inflammation and nerve injury promote astrocyt...  1745-6150
# 6300  The APOE genotype has emerged as the major gen...  1875-8908
# 6301  Mild cognitive impairment (MCI) is an intermed...  2694-0604
# 6302  Besides good glycemic control, also control of...  1452-8258
# 6303  APOE allelic variation is critical in brain ag...  1863-2661
#
#                                                 Journal  \
# 0                         Neuromuscular disorders : NMD
# 1     Biochemical and biophysical research communica...
# 2                                 Postgraduate medicine
# 3                                             Neurology
# 4                                      Medicina clinica
# ...                                                 ...
# 6299                                     Biology direct
# 6300               Journal of Alzheimer's disease : JAD
# 6301  Annual International Conference of the IEEE En...
# 6302                    Journal of medical biochemistry
# 6303                         Brain structure & function
#
#                         Location  Year FirstAuthorForename  \
# 0                      (9) 372-5  1999                 K E
# 1                    (265) 335-8  1999                 M L
# 2        (106) 72-6, 79-80, 82-3  1999                 D C
# 3                   (53) 1825-32  1999                   C
# 4                    (113) 441-3  1999                   V
# ...                          ...   ...                 ...
# 6299                     (18) 85  2023                Siyi
# 6300              (96) 1813-1825  2023                Bing
# 6301                  (2023) 1-5  2023              Nikita
# 6302                (42) 675-684  2023               Jasna
# 6303  10.1007/s00429-023-02731-x  2023             Hae Sol
#
#      FirstAuthorLastname FirstAuthorInitials  \
# 0               Morrison                  KE
# 1                 Brandi                  ML
# 2               Steffens                  DC
# 3                Geroldi                   C
# 4                Alvarez                   V
# ...                  ...                 ...
# 6299                 Liu                   S
# 6300                Zhao                   B
# 6301                Goel                   N
# 6302                Klen                   J
# 6303                Moon                  HS
#
#                                  FirstAuthorAffiliation FirstAuthorFullname
# 0     Neurosciences Group, Institiute of Molecular M...        K E Morrison
# 1     Department of Clinical Physiopathology, Univer...          M L Brandi
# 2     Department of Psychiatry and Behavioral Scienc...        D C Steffens
# 3        IRCCS San Giovanni di Dio-FBF, Brescia, Italy.           C Geroldi
# 4     Laboratorio de Genética Molecular, Instituto R...           V Alvarez
# ...                                                 ...                 ...
# 6299  Department of Physiology and Pathophysiology, ...            Siyi Liu
# 6300  Department of Neurology, Qingdao Municipal Hos...           Bing Zhao
# 6301                                                NaN         Nikita Goel
# 6302  University Medical Centre Ljubljana, Departmen...          Jasna Klen
# 6303  Department of Biomedical Engineering, Duke Uni...        Hae Sol Moon
#
# [6304 rows x 12 columns]

# %%
#there is one missing value in FirstAuthorFullname column
article["FirstAuthorFullname"].isnull().sum()
# Out:
# 1

# %%
article_years = article[["PMID", "Title", "Year"]]
article_years_counts = article_years['Year'].value_counts()
article_years_counts
# Out:
# 2023    438
# 2022    400
# 2021    375
# 2016    362
# 2014    342
# 2015    335
# 2020    330
# 2019    312
# 2017    298
# 2012    282
# 2013    279
# 2018    271
# 2011    267
# 2010    253
# 2008    229
# 2009    213
# 2007    196
# 2004    189
# 2006    177
# 2005    175
# 2003    148
# 2000    139
# 2002    125
# 2001    125
# 1999     34
# 2024      4
# 1998      3
# 1996      2
# 1997      1
# Name: Year, dtype: int64

# %%
#total 29 years include 2024
article_years_counts.shape
# Out:
# (29,)

# %%
#drop out 2024, so there is 28 years
years_counts_no2024 = article_years_counts[article_years_counts.index != 2024]
years_counts_no2024.shape
# Out:
# (28,)

# %%
article_years_counts.columns = ['Year', 'Amount']

# %%
#sort data by past years to recent years
article_years_counts_sorted = years_counts_no2024.sort_index()
article_years_counts_sorted
# Out:
# 1996      2
# 1997      1
# 1998      3
# 1999     34
# 2000    139
# 2001    125
# 2002    125
# 2003    148
# 2004    189
# 2005    175
# 2006    177
# 2007    196
# 2008    229
# 2009    213
# 2010    253
# 2011    267
# 2012    282
# 2013    279
# 2014    342
# 2015    335
# 2016    362
# 2017    298
# 2018    271
# 2019    312
# 2020    330
# 2021    375
# 2022    400
# 2023    438
# Name: Year, dtype: int64

# %%
#plot line graph of the total number papers in APOE field
article_years_counts_sorted.plot(title="The number of publications 1996-2023",
                                 xlabel="Year", ylabel="Number of Publications")
# Out:
# <Axes: title={'center': 'The number of publications 1996-2023'}, xlabel='Year', ylabel='Number of Publications'>

# %%
first = article["FirstAuthorFullname"].head()
first
# Out:
# 0    K E Morrison
# 1      M L Brandi
# 2    D C Steffens
# 3       C Geroldi
# 4       V Alvarez
# Name: FirstAuthorFullname, dtype: object

# %%
#count the nuber of papers per person
count_firstauthor = article["FirstAuthorFullname"].value_counts() #all first author = 5,061
count_firstauthor
# Out:
# Ramón Cacabelos                  18
# Richard J Caselli                13
# Alexander M Kulminski            12
# Yen Ying Lim                     10
# Fabricio Ferreira de Oliveira    10
#                                  ..
# Hulya Yılmaz-Aydogan              1
# Christian Wider                   1
# X Elcoroaristizabal Martín        1
# M P Vitek                         1
# Hae Sol Moon                      1
# Name: FirstAuthorFullname, Length: 5063, dtype: int64

# %%
#select researchers who has more than or equal 5 articles
firstauthors5 = count_firstauthor[count_firstauthor>=5]
#firstauthorstop = count_firstauthor.head(48)
firstauthors5 = firstauthors5.reset_index()
#>=5 papers = 48 #>5 papers = 25

# %%
firstauthors5.shape
# Out:
# (48, 2)

# %%
first_series = firstauthors5["index"].values

# %%
series = pd.Series(first_series)

# %%
#plot a bar chart top reasearchers who has more than 4 papers
count_firstauthor[count_firstauthor>4].plot(kind="bar",
                                            title="Top Researchers as first author by number of publication",
                                            xlabel="Author Full Name", ylabel="Number of Publications")
# Out:
# <Axes: title={'center': 'Top Researchers as first author by number of publication'}, xlabel='Author Full Name', ylabel='Number of Publications'>

# %%
#group by fullname
group_name = article.groupby(by="FirstAuthorFullname", group_keys=True)
#group by journal
group_journal = article.groupby(by="Journal", group_keys=True)

# %%
group_name[["Journal"]].apply(lambda x: x)
# Out:
#                                                                      Journal
# FirstAuthorFullname
#  Huriletemuer        1752               Journal of the neurological sciences
#  Yong-Peng Yu        5452                      BioMed research international
# A Achouri-Rassas     3530                                 Revue neurologique
# A Alvarez-Arcaya     166                       Acta neurologica Scandinavica
#                      219                                Neuroscience letters
# ...                                                                      ...
# Ágnes Fehér          2432                               Neuroscience letters
#                      2760                               Neuroscience letters
# Åsa Johansson        2677  Proceedings of the National Academy of Science...
# Øygunn A Utheim      1467                               Acta ophthalmologica
# Νarjes Nasiri-Ansari 4379                         Cardiovascular diabetology
#
# [6303 rows x 1 columns]

# %%
group_name.get_group("Richard J Caselli")
# Out:
#           PMID                                              Title  \
# 353   12071547  A distinctive interaction between memory and c...
# 710   15377739  A distinctive interaction between chronic anxi...
# 1279  17846270  Cognitive domain decline in healthy apolipopro...
# 1525  18779428  Correlating cerebral hypometabolism with futur...
# 1700  19605830  Longitudinal modeling of age-related memory de...
# 1746  19788866  Age-related memory decline and apolipoprotein ...
# 1827  20153809  Amyloid load in nondemented brains correlates ...
# 2457  22694803  Phenotypic differences between apolipoprotein ...
# 2458  22695623  Characterizing the preclinical stages of Alzhe...
# 2570  23102119  Longitudinal modeling of cognitive aging and t...
# 2826  24106134  Does an Alzheimer's disease susceptibility gen...
# 3282  25665170  Sex-based memory advantages and cognitive agin...
# 3788  27346168  Impact of Personality on Cognitive Aging: A Pr...
#
#                                                Abstract       ISSN  \
# 353   To correlate memory measures with a trait meas...  0161-8105
# 710   We correlated measures of problem solving (Wis...  0895-0172
# 1279  Memory declines more rapidly with age in apoli...  0003-9942
# 1525  Before symptomatic memory loss, healthy apolip...  1538-3687
# 1700  The APOE epsilon4 allele is associated with th...  1533-4406
# 1746  The APOE epsilon4 allele is associated with ri...  1944-7930
# 1827  179 Cognitively healthy adults enrolled in the...  1872-7972
# 2457  With the recent interest in Alzheimer's diseas...  1758-9193
# 2458  Studies of asymptomatic carriers of genes that...  1875-8908
# 2570  TOMM40 (translocase of the outer mitochondrial...  1552-5279
# 2826  The apolipoprotein E (APOE) e4 allele is the m...  1545-5017
# 3282  Education and related proxies for cognitive re...  1469-7661
# 3788  The aim of this study was to assess the associ...  1469-7661
#
#                                                 Journal              Location  \
# 353                                               Sleep           (25) 447-53
# 710   The Journal of neuropsychiatry and clinical ne...            (16) 320-9
# 1279                              Archives of neurology          (64) 1306-11
# 1525                              Archives of neurology           (65) 1231-6
# 1700                The New England journal of medicine          (361) 255-63
# 1746                                 Discovery medicine             (8) 47-50
# 1827                               Neuroscience letters          (473) 168-71
# 2457                     Alzheimer's research & therapy                (4) 20
# 2458               Journal of Alzheimer's disease : JAD  (33 Suppl 1) S405-16
# 2570  Alzheimer's & dementia : the journal of the Al...             (8) 490-5
# 2826                           Pediatric blood & cancer          (61) 1739-42
# 3282  Journal of the International Neuropsychologica...           (21) 95-104
# 3788  Journal of the International Neuropsychologica...           (22) 765-76
#
#       Year FirstAuthorForename FirstAuthorLastname FirstAuthorInitials  \
# 353   2002           Richard J             Caselli                  RJ
# 710   2004           Richard J             Caselli                  RJ
# 1279  2007           Richard J             Caselli                  RJ
# 1525  2008           Richard J             Caselli                  RJ
# 1700  2009           Richard J             Caselli                  RJ
# 1746  2009           Richard J             Caselli                  RJ
# 1827  2010           Richard J             Caselli                  RJ
# 2457  2012           Richard J             Caselli                  RJ
# 2458  2013           Richard J             Caselli                  RJ
# 2570  2012           Richard J             Caselli                  RJ
# 2826  2014           Richard J             Caselli                  RJ
# 3282  2015           Richard J             Caselli                  RJ
# 3788  2016           Richard J             Caselli                  RJ
#
#                                  FirstAuthorAffiliation FirstAuthorFullname
# 353   Department of Neurology, Mayo Clinic Scottsdal...   Richard J Caselli
# 710   Department of Neurology, Mayo Clinic Scottsdal...   Richard J Caselli
# 1279  Department of Neurology, Mayo Clinic, 13400 E ...   Richard J Caselli
# 1525  Department of Neurology, Mayo Clinic, 13400 E ...   Richard J Caselli
# 1700  Department of Neurology, Mayo Clinic Arizona, ...   Richard J Caselli
# 1746  Department of Neurology, Mayo Clinic, Scottsda...   Richard J Caselli
# 1827  Department of Neurology, Mayo Clinic Arizona, ...   Richard J Caselli
# 2457  Department of Neurology, Mayo Clinic Arizona, ...   Richard J Caselli
# 2458  Department of Neurology, Mayo Clinic Phoenix, ...   Richard J Caselli
# 2570  Department of Neurology, Mayo Clinic Arizona, ...   Richard J Caselli
# 2826  Department of Neurology, Mayo Clinic, Scottsda...   Richard J Caselli
# 3282  1Department of Neurology,Mayo Clinic Arizona,S...   Richard J Caselli
# 3788  1Department of Neurology,Mayo Clinic Arizona,S...   Richard J Caselli

# %%
#group by fullname and year
group_name_year = article.groupby(by=["FirstAuthorFullname","Year"], as_index=False)
count_name_year = group_name_year["PMID"].count()

# %%
count_name_year.dtypes
# Out:
# FirstAuthorFullname    object
# Year                    int64
# PMID                    int64
# dtype: object

# %%
#extract each researcher as first author with fullname, year and id column to a dataframe
eric_m_reiman = count_name_year[count_name_year['FirstAuthorFullname'] == "Eric M Reiman"]
kewei_chen = count_name_year[count_name_year['FirstAuthorFullname'] == "Kewei Chen"]
richard_j_caselli = count_name_year[count_name_year['FirstAuthorFullname'] == "Richard J Caselli"]

# %%
richard_j_caselli["cumsum"] = richard_j_caselli["PMID"].cumsum()
kewei_chen["cumsum"] = kewei_chen["PMID"].cumsum()
eric_m_reiman["cumsum"] = eric_m_reiman["PMID"].cumsum()
# Out:
# <ipython-input-25-2f8b285a8e63>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   richard_j_caselli["cumsum"] = richard_j_caselli["PMID"].cumsum()
# <ipython-input-25-2f8b285a8e63>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kewei_chen["cumsum"] = kewei_chen["PMID"].cumsum()
# <ipython-input-25-2f8b285a8e63>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eric_m_reiman["cumsum"] = eric_m_reiman["PMID"].cumsum()

# %%
#plot line chart with people as first author in each group
plt.figure()
ax = eric_m_reiman.plot(x="Year",y="cumsum",marker='o',label='Eric M Reiman')
kewei_chen.plot(x="Year",y="cumsum",marker='*', label="Kewei Chen", ax=ax)
richard_j_caselli.plot(x="Year",y="cumsum",marker="s", label="Richard J Caselli",ax=ax)
plt.xlim(2002,2020)
plt.ylim(0,15)
plt.xlabel("Year")
plt.ylabel("Number of Publications")
plt.legend()
plt.title("The cumulative number of publication")
plt.show()

# %% [markdown]
# # Authors

# %%
#import authors table
authors = pd.read_csv("/content/drive/MyDrive/Group 4/authors.APOE.csv")
authors
# Out:
#            PMID  AuthorN AuthorForename AuthorLastname AuthorInitials  \
# 0      10545039        1            K E       Morrison             KE
# 1      10545039        2              G         Steers              G
# 2      10545039        3              V       Dubowitz              V
# 3      10558867        1            M L         Brandi             ML
# 4      10558867        2              L      Becherini              L
# ...         ...      ...            ...            ...            ...
# 56887  38091051       10        Jasmine           King              J
# 56888  38091051       11        Allison    Ashley-Koch              A
# 56889  38091051       12          Darin          Clark              D
# 56890  38091051       13      Michael W           Lutz             MW
# 56891  38091051       14      Alexandra          Badea              A
#
#                                        AuthorAffiliation
# 0      Neurosciences Group, Institiute of Molecular M...
# 1                                                    NaN
# 2                                                    NaN
# 3      Department of Clinical Physiopathology, Univer...
# 4                                                    NaN
# ...                                                  ...
# 56887  Department of Biomedical Engineering, Duke Uni...
# 56888  Duke Molecular Physiology Institute, Duke Univ...
# 56889  Quantitative Imaging and Analysis Laboratory, ...
# 56890  Department of Neurology, Duke University Schoo...
# 56891  Department of Biomedical Engineering, Duke Uni...
#
# [56892 rows x 6 columns]

# %%
#merge forename and lastname to a new column
authors["Fullname"] = authors["AuthorForename"].fillna("") + ' ' + authors["AuthorLastname"]
authors
# Out:
#            PMID  AuthorN AuthorForename AuthorLastname AuthorInitials  \
# 0      10545039        1            K E       Morrison             KE
# 1      10545039        2              G         Steers              G
# 2      10545039        3              V       Dubowitz              V
# 3      10558867        1            M L         Brandi             ML
# 4      10558867        2              L      Becherini              L
# ...         ...      ...            ...            ...            ...
# 56887  38091051       10        Jasmine           King              J
# 56888  38091051       11        Allison    Ashley-Koch              A
# 56889  38091051       12          Darin          Clark              D
# 56890  38091051       13      Michael W           Lutz             MW
# 56891  38091051       14      Alexandra          Badea              A
#
#                                        AuthorAffiliation             Fullname
# 0      Neurosciences Group, Institiute of Molecular M...         K E Morrison
# 1                                                    NaN             G Steers
# 2                                                    NaN           V Dubowitz
# 3      Department of Clinical Physiopathology, Univer...           M L Brandi
# 4                                                    NaN          L Becherini
# ...                                                  ...                  ...
# 56887  Department of Biomedical Engineering, Duke Uni...         Jasmine King
# 56888  Duke Molecular Physiology Institute, Duke Univ...  Allison Ashley-Koch
# 56889  Quantitative Imaging and Analysis Laboratory, ...          Darin Clark
# 56890  Department of Neurology, Duke University Schoo...       Michael W Lutz
# 56891  Department of Biomedical Engineering, Duke Uni...      Alexandra Badea
#
# [56892 rows x 7 columns]

# %%
#extract id and fullname to a new datdaframe
id_name = authors[["PMID","Fullname"]]
id_name
# Out:
#            PMID             Fullname
# 0      10545039         K E Morrison
# 1      10545039             G Steers
# 2      10545039           V Dubowitz
# 3      10558867           M L Brandi
# 4      10558867          L Becherini
# ...         ...                  ...
# 56887  38091051         Jasmine King
# 56888  38091051  Allison Ashley-Koch
# 56889  38091051          Darin Clark
# 56890  38091051       Michael W Lutz
# 56891  38091051      Alexandra Badea
#
# [56892 rows x 2 columns]

# %%
id_name["Fullname"].isnull().sum()
# Out:
# 0

# %%
#count the number of name in th e dataframe
count_id = id_name["Fullname"].value_counts().head(48)
reset_id = count_id.reset_index()

# %%
series_id = pd.Series(reset_id["index"].values)

# %%
#merge top first researchers and top all authors
df = pd.concat([series,series_id],axis=1)
df["isin"] = df[0].isin(df[1])
df = df.rename(columns={0:"1st author",1:"all"})
df
# Out:
#                        1st author                       all   isin
# 0                 Ramón Cacabelos               Kaj Blennow  False
# 1               Richard J Caselli         Henrik Zetterberg   True
# 2           Alexander M Kulminski           David A Bennett  False
# 3                    Yen Ying Lim          David M Holtzman  False
# 4   Fabricio Ferreira de Oliveira        Patrick C N Rensen  False
# 5     Lilian Calderón-Garcidueñas             Eric M Reiman  False
# 6                 Francesco Panza                John Hardy   True
# 7                    Lars Bertram                   Lan Tan   True
# 8                   Nunzio Pomara         Ronald C Petersen  False
# 9                     Binbin Wang                Jin-Tai Yu  False
# 10              Federico Licastro          Philip Scheltens  False
# 11                  Eric M Reiman         Richard J Caselli   True
# 12            Katrine L Rasmussen     Gerard D Schellenberg  False
# 13                   Markus Donix                 Guojun Bu  False
# 14             Victoria C Merritt           Hilkka Soininen  False
# 15           Jean-Charles Lambert           Ralph N Martins  False
# 16             Katherine J Bangen           Colin L Masters  False
# 17                    Iwona Bojar           Clifford R Jack  False
# 18                        K W Kim                Kewei Chen  False
# 19                Vijay K Ramanan           Louis M Havekes  False
# 20                  Allen D Roses           Andrew J Saykin  False
# 21             Jaroslav A Hubacek  Margaret A Pericak-Vance  False
# 22                Clifford R Jack         Jonathan L Haines   True
# 23                   M O McCarron            Richard Mayeux  False
# 24             Chandra A Reynolds          Hans M G Princen  False
# 25                 Shea J Andrews          Dennis W Dickson  False
# 26                Niklas Mattsson             John C Morris  False
# 27                    David Bunce           Carlos Cruchaga  False
# 28                Thomas Espeseth    Wiesje M van der Flier  False
# 29                    Chang-En Yu        John Q Trojanowski  False
# 30               Paola Sebastiani          Lindsay A Farrer  False
# 31                    J M Ordovas              Mark W Bondi  False
# 32                  Davide Seripa            M Ilyas Kamboh   True
# 33                      Seth Love           David S Knopman  False
# 34                Patricia Huebbe                David Ames  False
# 35            Janina Krell-Roesch         Julie A Schneider  False
# 36              Cristiano Capurso             Davide Seripa  False
# 37                  Izumi Maezawa              Simon M Laws  False
# 38                     Jin-Tai Yu           J Wouter Jukema   True
# 39                 Donald M Lyall          G William Rebeck  False
# 40                 Michael W Lutz             Magda Tsolaki  False
# 41                         Lei Yu         Philip L De Jager  False
# 42            Raffaele Cacciaglia          Thomas J Montine  False
# 43                      Jing Zhao           Francesco Panza  False
# 44                    Simon Evans            Alison M Goate  False
# 45                       Xiao Luo               Ian J Deary  False
# 46             Elizabeth H Corder       Victor L Villemagne  False
# 47                        Yiyi Ma              Lars Bertram  False

# %%
#check the name that is in both dataframe
isin_true = df[df["isin"]]
isin_true
# Out:
#            1st author                all  isin
# 1   Richard J Caselli  Henrik Zetterberg  True
# 6     Francesco Panza         John Hardy  True
# 7        Lars Bertram            Lan Tan  True
# 11      Eric M Reiman  Richard J Caselli  True
# 22    Clifford R Jack  Jonathan L Haines  True
# 32      Davide Seripa     M Ilyas Kamboh  True
# 38         Jin-Tai Yu    J Wouter Jukema  True

# %%
#extract id and year from articles dataframe
id_year = article[["PMID","Year"]]
id_year
# Out:
#           PMID  Year
# 0     10545039  1999
# 1     10558867  1999
# 2     10560469  1999
# 3     10563634  1999
# 4     10570509  1999
# ...        ...   ...
# 6299  38071369  2023
# 6300  38073392  2023
# 6301  38083439  2023
# 6302  38084238  2023
# 6303  38091051  2023
#
# [6304 rows x 2 columns]

# %% [markdown]
# # Merge articles and authors table by PMID

# %%
#merge year to authors dataframe by PMID key
merge_id = id_year.merge(id_name, left_on='PMID', right_on='PMID')
merge_id
# Out:
#            PMID  Year             Fullname
# 0      10545039  1999         K E Morrison
# 1      10545039  1999             G Steers
# 2      10545039  1999           V Dubowitz
# 3      10558867  1999           M L Brandi
# 4      10558867  1999          L Becherini
# ...         ...   ...                  ...
# 56911  38091051  2023         Jasmine King
# 56912  38091051  2023  Allison Ashley-Koch
# 56913  38091051  2023          Darin Clark
# 56914  38091051  2023       Michael W Lutz
# 56915  38091051  2023      Alexandra Badea
#
# [56916 rows x 3 columns]

# %%
#group the dataframe above by name and year and count it with id
group_id = merge_id.groupby(by=["Fullname","Year"], as_index=False)
count_id = group_id["PMID"].count()
count_id
# Out:
#                                            Fullname  Year  PMID
# 0       Alzheimer's Disease Neuroimaging Initiative  2020     2
# 1       Alzheimer's Disease Neuroimaging Initiative  2021     1
# 2                                         Asmarinah  2014     1
# 3                                        Chunyuanwu  2013     1
# 4                                      De La Paz MA  2000     1
# ...                                             ...   ...   ...
# 49286                                 İrem L Atasoy  2018     1
# 49287                             Ľubica Peterajová  2020     1
# 49288                                  Željka Tomas  2011     1
# 49289                                Željka Vogrinc  2021     1
# 49290                          Νarjes Nasiri-Ansari  2018     1
#
# [49291 rows x 3 columns]

# %%
count_id[count_id['Fullname'] == "Patrick C N Rensen"]
# Out:
#                  Fullname  Year  PMID
# 35100  Patrick C N Rensen  2004     1
# 35101  Patrick C N Rensen  2005     1
# 35102  Patrick C N Rensen  2006     4
# 35103  Patrick C N Rensen  2007     3
# 35104  Patrick C N Rensen  2008     3
# 35105  Patrick C N Rensen  2009     1
# 35106  Patrick C N Rensen  2010     5
# 35107  Patrick C N Rensen  2011     3
# 35108  Patrick C N Rensen  2012     3
# 35109  Patrick C N Rensen  2013     4
# 35110  Patrick C N Rensen  2014     3
# 35111  Patrick C N Rensen  2015     4
# 35112  Patrick C N Rensen  2016     1
# 35113  Patrick C N Rensen  2017     2
# 35114  Patrick C N Rensen  2018     1
# 35115  Patrick C N Rensen  2019     1
# 35116  Patrick C N Rensen  2020     4
# 35117  Patrick C N Rensen  2021     4
# 35118  Patrick C N Rensen  2022     3
# 35119  Patrick C N Rensen  2023     8

# %%
#extract each researcher with fullname, year and count of id column to their own dataframe
#group1 from network
eric_m_reiman = count_id[count_id['Fullname'] == "Eric M Reiman"]
kewei_chen = count_id[count_id['Fullname'] == "Kewei Chen"]
richard_j_caselli = count_id[count_id['Fullname'] == "Richard J Caselli"]

# %%
#group1 from network
carlos_cruchaga = count_id[count_id['Fullname'] == "Carlos Cruchaga"]
colin_l_masters = count_id[count_id['Fullname'] == "Colin L Masters"]
john_c_morris = count_id[count_id['Fullname'] == "John C Morris"]
ralph_n = count_id[count_id['Fullname'] == "Ralph N Martins"]
david_m = count_id[count_id['Fullname'] == "David M Holtzman"]

# %%
#group2 from network
louis_M = count_id[count_id['Fullname'] == "Louis M Havekes"]
patrick_CN = count_id[count_id['Fullname'] == "Patrick C N Rensen"]
hans_MG = count_id[count_id['Fullname'] == "Hans M G Princen"]

# %%
#group3 from network
kaj_blennow = count_id[count_id['Fullname'] == "Kaj Blennow"]
henrik_zetterberg = count_id[count_id['Fullname'] == "Henrik Zetterberg"]

# %%
#group4 from network
lan_tan = count_id[count_id['Fullname'] == "Lan Tan"]
jintai_yu = count_id[count_id['Fullname'] == "Jin-Tai Yu"]

# %%
#group5 from network
clifford_r = count_id[count_id['Fullname'] == "Clifford R Jack"]
ronald_c = count_id[count_id['Fullname'] == "Ronald C Petersen"]

# %%
#sum calmulative of each researchers data freme
richard_j_caselli["cumsum"] = richard_j_caselli["PMID"].cumsum()
kewei_chen["cumsum"] = kewei_chen["PMID"].cumsum()
eric_m_reiman["cumsum"] = eric_m_reiman["PMID"].cumsum()
# Out:
# <ipython-input-45-22cc5f39a9a9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   richard_j_caselli["cumsum"] = richard_j_caselli["PMID"].cumsum()
# <ipython-input-45-22cc5f39a9a9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kewei_chen["cumsum"] = kewei_chen["PMID"].cumsum()
# <ipython-input-45-22cc5f39a9a9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eric_m_reiman["cumsum"] = eric_m_reiman["PMID"].cumsum()

# %%
#creat loop for sum calmulative of each researchers data freme
for name in [clifford_r,ronald_c]:
  name["cumsum"] = name["PMID"].cumsum()
# Out:
# <ipython-input-46-b5003222c501>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   name["cumsum"] = name["PMID"].cumsum()
# <ipython-input-46-b5003222c501>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   name["cumsum"] = name["PMID"].cumsum()

# %%
hans_MG
# Out:
#                Fullname  Year  PMID
# 16141  Hans M G Princen  2002     1
# 16142  Hans M G Princen  2003     2
# 16143  Hans M G Princen  2004     4
# 16144  Hans M G Princen  2006     1
# 16145  Hans M G Princen  2007     2
# 16146  Hans M G Princen  2008     3
# 16147  Hans M G Princen  2010     2
# 16148  Hans M G Princen  2011     1
# 16149  Hans M G Princen  2012     2
# 16150  Hans M G Princen  2013     2
# 16151  Hans M G Princen  2014     3
# 16152  Hans M G Princen  2015     2
# 16153  Hans M G Princen  2017     1
# 16154  Hans M G Princen  2018     2
# 16155  Hans M G Princen  2019     4
# 16156  Hans M G Princen  2020     2
# 16157  Hans M G Princen  2021     3
# 16158  Hans M G Princen  2022     1
# 16159  Hans M G Princen  2023     1

# %%
#plot a line graph for a group with the cumulative number of publications
plt.figure()
ax = clifford_r.plot(x="Year",y="cumsum",marker='o',label="Clifford R Jack")
ronald_c.plot(x="Year",y="cumsum",marker='*', label="Ronald C Petersen", ax=ax)
#john_c_morris.plot(x="Year",y="cumsum",marker="s", label="John C Morris",ax=ax)
#ralph_n.plot(x="Year",y="cumsum",marker='v', label="Ralph N Martins", ax=ax)
#david_m.plot(x="Year",y="cumsum",marker="d", label="David M Holtzman",ax=ax)
#plt.xlim(2002,2024)
#plt.ylim(0,60)
plt.xlabel("Year")
plt.ylabel("Number of Publications")
plt.legend()
plt.title("The cumulative number of publications")
plt.show()

# %% [markdown]
# # NetworkX

# %%
#plot a network graph of all arthors
import matplotlib.pyplot as plt
import networkx as nx
authors_top20 = id_name["Fullname"].value_counts().nlargest(20).index
authors_top20 = id_name[id_name["Fullname"].isin(authors_top20)]

G = nx.Graph()

for pmid, group in authors_top20.groupby('PMID'):
    authors = group['Fullname'].tolist()
    for author1 in authors:
        for author2 in authors:
            if author1 != author2:
              G.add_edge(author1, author2)
            else:
              G.add_node(author1)

pos = nx.spring_layout(G)

fig = plt.figure(figsize=(12, 8))
nx.draw(G, pos, with_labels=True, font_size=6, font_color='black',
        node_size=200, node_color='skyblue', edge_color='grey', linewidths=0.5)
plt.title('Author Collaborations according to PMID')
plt.show()
